# %% [markdown]
# https://machinelearningmastery.com/understanding-simple-recurrent-neural-networks-in-keras/

# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR

# %%
data = [
    244,228,153,140,55,34,30,28,29,41,88,199,230,245,247,135,34,33,27,26,28,39,86,188
]

# Tạo mảng numpy.array từ dữ liệu GDP
gas_array = np.array(data)

# In ra mảng để kiểm tra
print(gas_array)
# Out:
# [244 228 153 140  55  34  30  28  29  41  88 199 230 245 247 135  34  33
#   27  26  28  39  86 188]

# %%
lag = 1  # Độ trễ 1

X = []
y = []

# Tạo dữ liệu đầu vào (X) và dữ liệu mục tiêu (y)
for i in range(len(gas_array) - lag):
    X.append(gas_array[i:i + lag])
    y.append(gas_array[i + lag])

# Chuyển đổi X và y thành mảng numpy.array
X = np.array(X)
y = np.array(y)

# Chuẩn hóa dữ liệu
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Tạo mô hình SVR
svr_model = SVR(C=1.0, epsilon=0.1, kernel='rbf')

# Huấn luyện mô hình
svr_model.fit(X_train, y_train)

# Dự báo trên tập kiểm tra
y_pred = svr_model.predict(X_test)

# %%
# Vẽ biểu đồ
plt.figure(figsize=(10, 6))

# Vẽ giá trị thực (y_test)
plt.plot(y_test, label='y_test', color='red')

# Vẽ giá trị dự đoán (y_pred)
plt.plot(y_pred, label='y_pred', color='green' )

# Thêm tiêu đề và nhãn trục
plt.title('So sánh giữa y_test và y_pred')
plt.xlabel('Số điểm dữ liệu')
plt.ylabel('Gas Use')

# Thêm chú thích
plt.legend()

# Hiển thị biểu đồ
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Tính SSE (Sum of Squared Errors)
sse = np.sum((y_test - y_pred) ** 2)
print("Sum of Squared Errors (SSE):", sse)

# Tính R-squared (Hệ số xác định)
r_squared = r2_score(y_test, y_pred)
print("R-squared:", r_squared)
# Out:
# Mean Squared Error: 5397.344751057073
# Sum of Squared Errors (SSE): 26986.723755285366
# R-squared: 0.0480604830018001

# %%
# Tính RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error (RMSE):", rmse)

# Tính MAE
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Tính MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Root Mean Squared Error (RMSE): 73.46662338134966
# Mean Absolute Error (MAE): 55.387415065870314
# Mean Absolute Percentage Error (MAPE): 83.37165276704853
